# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("filled_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    country        date  daily_vaccinations   vaccines
# 0           0  Argentina  12/29/2020              6483.0  Sputnik V
# 1           1  Argentina  12/30/2020             15656.0  Sputnik V
# 2           2  Argentina  12/31/2020             15656.0  Sputnik V
# 3           3  Argentina    1/1/2021             11070.0  Sputnik V
# 4           4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020              6483.0
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             1502 non-null   object
#  1   date                1502 non-null   object
#  2   daily_vaccinations  1502 non-null   float64
#  3   vaccines            1502 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 47.1+ KB

# %%
df.groupby("country").agg(["min", "max", "std","mean","median"])
# Out:
#                      daily_vaccinations                            \
#                                     min        max            std
# country
# Argentina                        6483.0    15656.0    2616.399285
# Austria                          3368.0    12552.0    3273.981069
# Bahrain                           943.0    11106.0    2557.463294
# Belgium                             1.0    13135.0    5254.099266
# Brazil                            112.0    99928.0   39530.203954
# Bulgaria                          472.0     2889.0     465.154402
# Canada                            866.0    39910.0   14601.764692
# Chile                              51.0     6328.0    2170.022851
# China                          187500.0   714286.0  155617.069553
# Costa Rica                        240.0     2158.0     775.863296
# Croatia                           989.0     3346.0     820.304118
# Cyprus                            534.0     1022.0     185.546985
# ...

# %% [markdown]
# # Implement code to list the top-3 countries with highest median daily vaccination numbers

# %%
median= df['median'] = df.groupby(by='country')['daily_vaccinations'].transform('median')

# %%
median2=df.loc[df['median'].sort_values(ascending=False).index]
median2
# Out:
#             country        date  daily_vaccinations                  vaccines  \
# 1425  United States  12/23/2020            150606.0  Moderna, Pfizer/BioNTech
# 1452  United States   1/19/2021            911493.0  Moderna, Pfizer/BioNTech
# 1446  United States   1/13/2021            710238.0  Moderna, Pfizer/BioNTech
# 1447  United States   1/14/2021            747082.0  Moderna, Pfizer/BioNTech
# 1448  United States   1/15/2021            798707.0  Moderna, Pfizer/BioNTech
# ...             ...         ...                 ...                       ...
# 622         Iceland   1/21/2021               312.0  Moderna, Pfizer/BioNTech
# 623         Iceland   1/22/2021               560.0  Moderna, Pfizer/BioNTech
# 624         Iceland   1/23/2021               809.0  Moderna, Pfizer/BioNTech
# 626         Iceland   1/25/2021              1306.0  Moderna, Pfizer/BioNTech
# 750          Kuwait  12/28/2020                 0.0           Pfizer/BioNTech
#
#         median
# 1425  378253.0
# ...

# %%
sorting = median2.groupby('country')['median'].median().sort_values(ascending=False)

# %%
sorting.head(3)
# Out:
# country
# United States    378253.0
# China            276786.0
# India            173922.0
# Name: median, dtype: float64

# %% [markdown]
# ### 1-United States    378253.0
# ### 2-China            276786.0
# ### 3-India            173922.0
